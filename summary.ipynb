# %% [markdown]
# ## Types of Data:
# ### Categotical data
# 1. ordinal -- order value
# 2. nominal -- namable value
# ### Numerical data
# 1. descrite -- countable values
# 2. continuous -- continuous values

# %% [markdown]
# ## Types of Encoding:
# ### 1.Label Encoding
# ### 2.On-hot Encoding

# %% [markdown]
# ### Types of Sampling Methods:
# 1. simple random sampling
# 2. Stractified sampling
# 3. Clustering sampling
# 4. Systematic sampling

# %% [markdown]
# ### Types of Statistics:
# 1. Descriptive Statistics
# 2. Inferential Statistics
